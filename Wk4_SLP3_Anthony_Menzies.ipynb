# %%
#Importing packages
from selenium import webdriver
import pandas as pd

# %%
driver = webdriver.Chrome('C:/Users/Anthony/chromedriver.exe')

# %%
driver.get('https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/')

# %%
class CarForumCrawler(): 
    def __init__(self, start_link):
        self.link_to_explore = start_link 
        self.comments = pd.DataFrame(columns = ['Date','user_id','comments'])
        self.driver = webdriver.Chrome(executable_path='C:/Users/Anthony/chromedriver.exe')            
        self.pagecount = 1
        self.next = True
                
    def run(self):
        while self.next:
            if self.pagecount >=5:
                self.save_data_to_file()
                self.next = False
            try:
                self.driver.get(self.link_to_explore+"p"+str(self.pagecount))
                self.driver.implicitly_wait(15)
                self.extract_data()      
                self.pagecount = self.pagecount + 1
            except:
                print ("Cannot get the page " + self.link_to_explore)
                self.next = False
                raise
            
    def extract_data(self):
        ids = self.driver.find_elements_by_xpath("//*[contains(@id,'Comment_')]")
        comment_ids = []
        
        for i in ids:
            comment_ids.append(i.get_attribute('id'))
        
        for x in comment_ids:
            #Extract dates from for each user on a page
            user_date = self.driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[2]/span[1]/a/time')[0]
            date = user_date.get_attribute('title')

            #Extract user ids from each user on a page
            userid_element = self.driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[2]/div[1]/span[1]/a[2]')[0]
            userid = userid_element.text

            #Extract Message for each user on a page
            user_message = self.driver.find_elements_by_xpath('//*[@id="' + x +'"]/div/div[3]/div/div[1]')[0]
            comment = user_message.text
                               
            #Adding date, userid and comment for each user in a dataframe    
            self.comments.loc[len(self.comments)] = [date,userid,comment]  

    def save_data_to_file(self):
    #we save the dataframe content to a CSV file
        self.comments.to_csv ('comments.csv', index = None, header=True)
    def close_spider(self):
    #end the session
        self.driver.quit()

# %%
if __name__ == '__main__':
    url = 'https://forums.edmunds.com/discussion/2864/general/x/entry-level-luxury-performance-sedans/'        
    try:
        mycrawler = CarForumCrawler(url)
        mycrawler.run()
        mycrawler.close_spider()
    except:
        raise

# %%
df = pd.read_csv (r'C:/Users/Anthony/PycharmProjects/DataScienceMasterClass1/weekly_activities/week_4/comments.csv')

# %%
df
# Out:
#                            Date        user_id  \
# 0         March 24, 2002 9:54PM          merc1
# 1        March 24, 2002 11:06PM         fredvh
# 2         March 25, 2002 9:02AM  blueguydotcom
# 3         March 25, 2002 3:04PM    hungrywhale
# 4         March 25, 2002 4:44PM           riez
# 5        March 26, 2002 12:20PM  blueguydotcom
# 6         March 26, 2002 1:02PM    hungrywhale
# 7         March 26, 2002 1:45PM  blueguydotcom
# 3    And no manual tranny. That may not matter to y...
# 4    One beauty of BMW 3 Series is that there are s...
# 5    good grief, so you wait 9 months for the manua...
# 6    I'll give it a fair shot when the manual comes...
# 7    I understand it's not about the speed. I reall...
# 8    It sounds like you know why I won't even put i...
# 9    Is there such a thing as an automatic-only tru...
# 10   If I had to rank the entry lux performance sed...
# 11   Hey my friend, dig this, in Australia, the ONL...
# 12   >"Is there such a thing as an automatic-only t...
# 13   I think what riez and I are trying to say is n...
# 14                                                amen
# 15   In this class, the best bang for the buck has ...
# 16   Even at 29k for a 35k msrp IS300, I passed on ...
# 17   Never liked a lexus, and probably never will. ...
# 18   "I would buy the IS as a Toyota but not a Lexu...
# 19   I couldn't have said it better myself. I'll le...
# 20   Thanks Riez! Let me know when you do. I'm sure...
# 21   mbarto... As regards the "bribes" issue, you'v...
# 22   So if someone were looking to purchase a new p...
# 23   Since it has to have a manual transmission and...
# 24   The TL should be up for redesign in a few year...
# 25   The new ES is a very smart looking car. Notwit...
# 26   Um...you left off the Infiniti G35 and it's bl...
# 27   Sorry, I thought that I had already taken up t...
# 28   Go drive one. They're a blast and for the mone...
# 29   I can't make a decision. I was set on the MB C...
# ..                                                 ...
# 170  Ah, this reminds me of word problems in math c...
# 171  From everything I've read the percentage of af...
# 172                           ... is about 19,200 cars
# 173  J D Power & [non-permissible content removed]....
# 174  It's definitely not overstated. There have bee...
# 175  I am in outside sales driving 30-35K miles per...
# 176  I think that Honda willingness to extend the t...
# 177  I don't think Honda issued any recalls for the...
# 178  ooo... that must have been exciting....\r\n\r\...
# 179  GTP lease ended in December 2001.\r\nWife got ...
# 180  Audi A4, the model with memory seats and mirro...
# 181  A reporter is looking for consumers who have b...
# 182  Actually I'm looking into getting a car in thi...
# 183  I'm thinking one factor worth considering is w...
# 184  cjs2002... What are your criteria? What is imp...
# 185  also check out Chrysler 300M, especially the S...
# 186  well I've started researching many of these ve...
# 187  cjs2002... Since you'll only go automatic tran...
# 188  have you looked at 300M yet? They are very nic...
# 189  I'm glad you have decided to buy something oth...
# 190  just a thought ... the MB that I'm talking abo...
# 191  cjs2002... You wrote, "but the IS to me seems ...
# 192  IS could use some more HP. Interior is kind of...
# 193  sorry about the comparison I know they aren't ...
# 194  cjs2002... You have me thoroughly confused. Ar...
# 195  I had a 300M for 3 years and - no problems. I'...
# 196  lol sorry for the confusion... everything I'm ...
# 197  cjs2002... Not sure what to make. Pulled up yo...
# 198  I've been really pleased with the A4 with Quat...
# 199  I had many problems with my G35 sedan, but the...
#
# [200 rows x 3 columns]
